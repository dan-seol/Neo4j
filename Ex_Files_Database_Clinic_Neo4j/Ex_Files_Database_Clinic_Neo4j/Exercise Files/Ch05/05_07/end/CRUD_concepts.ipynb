# %% [markdown]
# # CRUD Concepts

# %% [markdown]
# ## Data model
#
#
# <img src="https://dl.dropboxusercontent.com/u/67572426/datamodel_sm.png">

# %% [markdown]
# ## Connect to Neo4j
#
# We use the [Neo4j Bolt Driver](http://neo4j.com/docs/api/python-driver/current/) to connect to Neo4j and execute Cypher queries.

# %%
# First we install the neo4j-driver package
# !pip install neo4j-driver
# Out:
# Requirement already satisfied: neo4j-driver in /Users/williamlyon/anaconda/lib/python3.6/site-packages

# %%
from neo4j.v1 import GraphDatabase

# %%
# instantiate driver object
driver = GraphDatabase.driver("bolt://localhost:7687", auth=("neo4j", "letmein"))

# %%
# Hello world
with driver.session() as session:
    result = session.run("MATCH (a) RETURN COUNT(a) AS num")
    
    for record in result:
        print("Number of nodes in the database: %i" % record['num'])
# Out:
# Number of nodes in the database: 0

# %% [markdown]
# ## CREATE
#
# ### Create Characters

# %%
with driver.session() as session:
    session.run("CREATE CONSTRAINT ON (c:Character) ASSERT c.name IS UNIQUE;")

# %%
# Query to create Character node
create_character_query = '''
MERGE (c:Character {name: $name})
'''

# %%
with driver.session() as session:
    with open("data/characters.txt") as f:
        for line in f:
            # strip whitespace
            text = line.strip()
            # execute create_character_query, passing name parameter   
            session.run(create_character_query, parameters={'name': text})

# %% [markdown]
# ### Create Line nodes
#
# > For each line in the text, CREATE a corresponding record in the database. Each record will include the name of the character speaking, the (absolute) line number of the phrase and the phrase itself, trimmed of any leading or following spaces

# %%
# Query to add a line to the database
create_line_query = '''
CREATE (l:Line {text: $line_text, number: $line_num})
WITH l
MATCH (c:Character) WHERE c.name = $current_character
CREATE (l)<-[:SPEAKS]-(c)
'''

# %%
# create an empty set
characters = set()

# fetch all Character names from the database
get_characters_query = '''
MATCH (c:Character)
RETURN c.name AS name
'''

# for each Character name, add it to the characters set
with driver.session() as session:
    result = session.run(get_characters_query)
    for record in result:
        characters.add(record['name'])

characters
# Out:
# {'BOTTOM',
#  'COBWEB',
#  'DEMETRIUS',
#  'EGEUS',
#  'FLUTE',
#  'HELENA',
#  'HERMIA',
#  'HIPPOLYTA',
#  'LYSANDER',
#  'MOTH',
#  'MUSTARDSEED',
#  'OBERON',
#  'PEASEBLOSSOM',
#  'PHILOSTRATE',
#  'PUCK',
#  'QUINCE',
#  'SNOUT',
#  'SNUG',
#  'STARVELING',
#  'THESEUS',
#  'TITANIA'}

# %%
# import the time 
import time

# %%
line_num = 0

begin = time.time()
with driver.session() as session:
    with open("data/A_Midsummer_Nights_Dream.txt") as f:
        current_character = ''
        for line in f:
            # strip leading and trailing whitespace
            text = line.strip()
            # is line the character speaking?
            if text in characters:
                current_character = text
            else:
                line_num += 1
                session.run(create_line_query, parameters={
                    'line_text': text,
                    'line_num': line_num,
                    'current_character': current_character
                })
            # insert line into database
            
    end = time.time()
    create_time = (end-begin)/line_num * 1000

print(str(create_time))
# Out:
# 0.30182105813272264

# %% [markdown]
# ## UPDATE
#
# > For each record in the database, search for character names, convert them to UPPERCASE, then UPDATE the record in the database

# %%
# query to update 
update_query = '''
WITH $character AS character
WITH substring(character,0,1) + toLower(substring(character,1)) AS casedChar, character

MATCH (l:Line) WHERE toLower(l.text) CONTAINS toLower(character)
SET l.text = replace(l.text, casedChar, character)
RETURN COUNT(l) AS num
'''

# %%
update_count = 0

with driver.session() as session:
    begin = time.time()
    for c in characters:
        # Update the lines mentioning this character
        result = session.run(update_query, parameters = {'character': c})
        # increment update_count
        record = result.single()
        update_count += record['num']
    end = time.time()
    update_time = (end-begin)/update_count * 1000
    print(update_time)
# Out:
# 0.44376305911851965

# %% [markdown]
# ## DELETE
#
# > For each record in the database, the instructor will also need to DELETE any lines that start with “ENTER” , “EXIT” , “ACT” , or “SCENE”

# %%
# query to delete stop words
delete_query = '''
WITH ['ENTER', 'EXIT', 'ACT', 'SCENE'] AS words
MATCH (l:Line) WHERE any(x IN words WHERE toLower(l.text) STARTS WITH toLower(x))
DETACH DELETE l
RETURN COUNT(l) AS num
'''

# %%
with driver.session() as session:
    begin = time.time()
    result = session.run(delete_query)
    record = result.single()
    num_lines = record['num']
    end = time.time()
    delete_time = (end-begin) / num_lines * 1000
    print(delete_time)
# Out:
# 0.4598163976901915

# %% [markdown]
# ## READ
#
# When all other tasks are complete, the next step will be to READ each line and print it out to console

# %%
# query to read lines
read_lines_query = '''
MATCH (l:Line) RETURN l.text AS text, l.number AS linenum
'''

# %%
with driver.session() as session:
    begin = time.time()
    # read each line from the datbase
    result = session.run(read_lines_query)
    for record in result:
    # print each line
        print("%i: %s" % (record['linenum'], record['text']))
    end = time.time()
    
    # get number of lines in database
    result = session.run("MATCH (l:Line) RETURN COUNT(l) AS num")
    numlines = result.single()['num']
    
    
    
    read_time = (end-begin)/numlines * 1000
    print(str(read_time))
# Out:
# 1: A Midsummer Night's Dream
# 2: Shakespeare homepage | Midsummer Night's Dream | Entire play
# 5:
# 7: Now, fair HIPPOLYTA, our nuptial hour
# 8: Draws on apace; four happy days bring in
# 9: Another moon: but, O, methinks, how slow
# 10: This old moon wanes! she lingers my desires,
# 11: Like to a step-dame or a dowager
# 12: Long withering out a young man revenue.
# 13: Four days will quickly steep themselves in night;
# 14: Four nights will quickly dream away the time;
# 15: And then the moon, like to a silver bow
# 16: New-bent in heaven, shall behold the night
# 17: Of our solemnities.
# 18: Go, PHILOSTRATE,
# 19: Stir up the Athenian youth to merriments;
# 20: Awake the pert and nimble spirit of mirth;
# 21: Turn melancholy forth to funerals;
# 22: The pale companion is not for our pomp.
# 24: HIPPOLYTA, I woo'd thee with my sword,
# 25: And won thy love, doing thee injuries;
# 26: But I will wed thee in another key,
# 27: With pomp, with triumph and with revelling.
# 29: Happy be THESEUS, our renowned duke!
# 30: Thanks, good EGEUS: what's the news with thee?
# 31: Full of vexation come I, with complaint
# 32: Against my child, my daughter HERMIA.
# 33: Stand forth, DEMETRIUS. My noble lord,
# 34: This man hath my consent to marry her.
# 35: Stand forth, LYSANDER: and my gracious duke,
# 36: This man hath bewitch'd the bosom of my child;
# 37: Thou, thou, LYSANDER, thou hast given her rhymes,
# 38: And interchanged love-tokens with my child:
# 39: Thou hast by moonlight at her window sung,
# 40: With feigning voice verses of feigning love,
# 41: And stolen the impression of her fantasy
# 42: With bracelets of thy hair, rings, gawds, conceits,
# 43: Knacks, trifles, nosegays, sweetmeats, messengers
# 44: Of strong prevailment in unharden'd youth:
# 45: With cunning hast thou filch'd my daughter's heart,
# 46: Turn'd her obedience, which is due to me,
# 47: To stubborn harshness: and, my gracious duke,
# 48: Be it so she; will not here before your grace
# 49: Consent to marry with DEMETRIUS,
# 50: I beg the ancient privilege of Athens,
# 51: As she is mine, I may dispose of her:
# 52: Which shall be either to this gentleman
# 53: Or to her death, according to our law
# 54: Immediately provided in that case.
# 55: What say you, HERMIA? be advised fair maid:
# 56: To you your father should be as a god;
# 57: One that composed your beauties, yea, and one
# 58: To whom you are but as a form in wax
# 59: By him imprinted and within his power
# 60: To leave the figure or disfigure it.
# 61: DEMETRIUS is a worthy gentleman.
# 62: So is LYSANDER.
# 63: In himself he is;
# 64: But in this kind, wanting your father's voice,
# 65: The other must be held the worthier.
# 66: I would my father look'd but with my eyes.
# 67: Rather your eyes must with his judgment look.
# 68: I do entreat your grace to pardon me.
# 69: I know not by what power I am made bold,
# 70: Nor how it may concern my modesty,
# 71: In such a presence here to plead my thoughts;
# 72: But I beseech your grace that I may know
# 73: The worst that may befall me in this case,
# 74: If I refuse to wed DEMETRIUS.
# 75: Either to die the death or to abjure
# 76: For ever the society of men.
# 77: Therefore, fair HERMIA, question your desires;
# 78: Know of your youth, examine well your blood,
# 79: Whether, if you yield not to your father's choice,
# 80: You can endure the livery of a nun,
# 81: For aye to be in shady cloister mew'd,
# 82: To live a barren sister all your life,
# 83: Chanting faint hymns to the cold fruitless moon.
# 84: Thrice-blessed they that master so their blood,
# 85: To undergo such maiden pilgrimage;
# 86: But earthlier happy is the rose distill'd,
# 87: Than that which withering on the virgin thorn
# 88: Grows, lives and dies in single blessedness.
# 89: So will I grow, so live, so die, my lord,
# 90: Ere I will my virgin patent up
# 91: Unto his lordship, whose unwished yoke
# 92: My soul consents not to give sovereignty.
# 93: Take time to pause; and, by the next new moon--
# 94: The sealing-day betwixt my love and me,
# 95: For everlasting bond of fellowship--
# 96: Upon that day either prepare to die
# 97: For disobedience to your father's will,
# 98: Or else to wed DEMETRIUS, as he would;
# 99: Or on Diana's altar to protest
# 100: For aye austerity and single life.
# 101: Relent, sweet HERMIA: and, LYSANDER, yield
# 102: Thy crazed title to my certain right.
# 103: You have her father's love, DEMETRIUS;
# 104: Let me have HERMIA's: do you marry him.
# 105: Scornful LYSANDER! true, he hath my love,
# 106: And what is mine my love shall render him.
# 107: And she is mine, and all my right of her
# 108: I do estate unto DEMETRIUS.
# 109: I am, my lord, as well derived as he,
# 110: As well possess'd; my love is more than his;
# 111: My fortunes every way as fairly rank'd,
# 112: If not with vantage, as DEMETRIUS';
# 113: And, which is more than all these boasts can be,
# 114: I am beloved of beauteous HERMIA:
# 115: Why should not I then prosecute my right?
# 116: DEMETRIUS, I'll avouch it to his head,
# 117: Made love to Nedar's daughter, HELENA,
# 118: And won her soul; and she, sweet lady, dotes,
# 119: Devoutly dotes, dotes in idolatry,
# 120: Upon this spotted and inconstant man.
# 121: I must confess that I have heard so much,
# 122: And with DEMETRIUS thought to have spoke thereof;
# 123: But, being over-full of self-affairs,
# 124: My mind did lose it. But, DEMETRIUS, come;
# 125: And come, EGEUS; you shall go with me,
# 126: I have some private schooling for you both.
# 127: For you, fair HERMIA, look you arm yourself
# 128: To fit your fancies to your father's will;
# 129: Or else the law of Athens yields you up--
# 130: Which by no means we may extenuate--
# 131: To death, or to a vow of single life.
# 132: Come, my HIPPOLYTA: what cheer, my love?
# 133: DEMETRIUS and EGEUS, go along:
# 134: I must employ you in some business
# 135: Against our nuptial and confer with you
# 136: Of something nearly that concerns yourselves.
# 137: With duty and desire we follow you.
# 138: Exeunt all but LYSANDER and HERMIA
# 139: How now, my love! why is your cheek so pale?
# 140: How chance the roses there do fade so fast?
# 141: Belike for want of rain, which I could well
# 142: Beteem them from the tempest of my eyes.
# 143: Ay me! for aught that I could ever read,
# 144: Could ever hear by tale or history,
# 145: The course of true love never did run smooth;
# 146: But, either it was different in blood,--
# 147: O cross! too high to be enthrall'd to low.
# 148: Or else misgraffed in respect of years,--
# 149: O spite! too old to be engaged to young.
# 150: Or else it stood upon the choice of friends,--
# 151: O hell! to choose love by another's eyes.
# 152: Or, if there were a sympathy in choice,
# 153: War, death, or sickness did lay siege to it,
# 154: Making it momentany as a sound,
# 155: Swift as a shadow, short as any dream;
# 156: Brief as the lightning in the collied night,
# 157: That, in a spleen, unfolds both heaven and earth,
# 158: And ere a man hath power to say 'Behold!'
# 159: The jaws of darkness do devour it up:
# 160: So quick bright things come to confusion.
# 161: If then true lovers have been ever cross'd,
# 162: It stands as an edict in destiny:
# 163: Then let us teach our trial patience,
# 164: Because it is a customary cross,
# 165: As due to love as thoughts and dreams and sighs,
# 166: Wishes and tears, poor fancy's followers.
# 167: A good persuasion: therefore, hear me, HERMIA.
# 168: I have a widow aunt, a dowager
# 169: Of great revenue, and she hath no child:
# 170: From Athens is her house remote seven leagues;
# 171: And she respects me as her only son.
# 172: There, gentle HERMIA, may I marry thee;
# 173: And to that place the sharp Athenian law
# 174: Cannot pursue us. If thou lovest me then,
# 175: Steal forth thy father's house to-morrow night;
# 176: And in the wood, a league without the town,
# 177: Where I did meet thee once with HELENA,
# 178: To do observance to a morn of May,
# 179: There will I stay for thee.
# 180: My good LYSANDER!
# 181: I swear to thee, by Cupid's strongest bow,
# 182: By his best arrow with the golden head,
# 183: By the simplicity of Venus' doves,
# 184: By that which knitteth souls and prospers loves,
# 185: And by that fire which burn'd the Carthage queen,
# 186: When the false Troyan under sail was seen,
# 187: By all the vows that ever men have broke,
# 188: In number more than ever women spoke,
# 189: In that same place thou hast appointed me,
# 190: To-morrow truly will I meet with thee.
# 191: Keep promise, love. Look, here comes HELENA.
# 193: God speed fair HELENA! whither away?
# 194: Call you me fair? that fair again unsay.
# 195: DEMETRIUS loves your fair: O happy fair!
# 196: Your eyes are lode-stars; and your tongue's sweet air
# 197: More tuneable than lark to shepherd's ear,
# 198: When wheat is green, when hawthorn buds appear.
# 199: Sickness is catching: O, were favour so,
# 200: Yours would I catch, fair HERMIA, ere I go;
# 201: My ear should catch your voice, my eye your eye,
# 202: My tongue should catch your tongue's sweet melody.
# 203: Were the world mine, DEMETRIUS being bated,
# 204: The rest I'd give to be to you translated.
# 205: O, teach me how you look, and with what art
# 206: You sway the motion of DEMETRIUS' heart.
# 207: I frown upon him, yet he loves me still.
# 208: O that your frowns would teach my smiles such skill!
# 209: I give him curses, yet he gives me love.
# 210: O that my prayers could such affection move!
# 211: The more I hate, the more he follows me.
# 212: The more I love, the more he hateth me.
# 213: His folly, HELENA, is no fault of mine.
# 214: None, but your beauty: would that fault were mine!
# 215: Take comfort: he no more shall see my face;
# 216: LYSANDER and myself will fly this place.
# 217: Before the time I did LYSANDER see,
# 218: Seem'd Athens as a paradise to me:
# 219: O, then, what graces in my love do dwell,
# 220: That he hath turn'd a heaven unto a hell!
# 221: Helen, to you our minds we will unfold:
# 222: To-morrow night, when Phoebe doth behold
# 223: Her silver visage in the watery glass,
# 224: Decking with liquid pearl the bladed grass,
# 225: A time that lovers' flights doth still conceal,
# 226: Through Athens' gates have we devised to steal.
# 227: And in the wood, where often you and I
# 228: Upon faint primrose-beds were wont to lie,
# 229: Emptying our bosoms of their counsel sweet,
# 230: There my LYSANDER and myself shall meet;
# 231: And thence from Athens turn away our eyes,
# 232: To seek new friends and stranger companies.
# 233: Farewell, sweet playfellow: pray thou for us;
# 234: And good luck grant thee thy DEMETRIUS!
# 235: Keep word, LYSANDER: we must starve our sight
# 236: From lovers' food till morrow deep midnight.
# 237: I will, my HERMIA.
# 239: HELENA, adieu:
# 240: As you on him, DEMETRIUS dote on you!
# 242: How happy some o'er other some can be!
# 243: Through Athens I am thought as fair as she.
# 244: But what of that? DEMETRIUS thinks not so;
# 245: He will not know what all but he do know:
# 246: And as he errs, doting on HERMIA's eyes,
# 247: So I, admiring of his qualities:
# 248: Things base and vile, folding no quantity,
# 249: Love can transpose to form and dignity:
# 250: Love looks not with the eyes, but with the mind;
# 251: And therefore is wing'd Cupid painted blind:
# 252: Nor hath Love's mind of any judgement taste;
# 253: Wings and no eyes figure unheedy haste:
# 254: And therefore is Love said to be a child,
# 255: Because in choice he is so oft beguiled.
# 256: As waggish boys in game themselves forswear,
# 257: So the boy Love is perjured every where:
# 258: For ere DEMETRIUS look'd on HERMIA's eyne,
# 259: He hail'd down oaths that he was only mine;
# 260: And when this hail some heat from HERMIA felt,
# 261: So he dissolved, and showers of oaths did melt.
# 262: I will go tell him of fair HERMIA's flight:
# 263: Then to the wood will he to-morrow night
# 264: Pursue her; and for this intelligence
# 265: If I have thanks, it is a dear expense:
# 266: But herein mean I to enrich my pain,
# 267: To have his sight thither and back again.
# 270:
# 272: Is all our company here?
# 273: You were best to call them generally, man by man,
# 274: according to the scrip.
# 275: Here is the scroll of every man's name, which is
# 276: thought fit, through all Athens, to play in our
# 277: interlude before the duke and the duchess, on his
# 278: wedding-day at night.
# 279: First, good Peter QUINCE, say what the play treats
# 280: on, then read the names of the actors, and so grow
# 281: to a point.
# 282: Marry, our play is, The most lamentable comedy, and
# 283: most cruel death of Pyramus and Thisby.
# 284: A very good piece of work, I assure you, and a
# 285: merry. Now, good Peter QUINCE, call forth your
# 287: Answer as I call you. Nick BOTTOM, the weaver.
# 288: Ready. Name what part I am for, and proceed.
# 289: You, Nick BOTTOM, are set down for Pyramus.
# 290: What is Pyramus? a lover, or a tyrant?
# 291: A lover, that kills himself most gallant for love.
# 292: That will ask some tears in the true performing of
# 293: it: if I do it, let the audience look to their
# 294: eyes; I will move storms, I will condole in some
# 295: measure. To the rest: yet my chief humour is for a
# 296: tyrant: I could play Ercles rarely, or a part to
# 297: tear a cat in, to make all split.
# 298: The raging rocks
# 299: And shivering shocks
# 300: Shall break the locks
# 301: Of prison gates;
# 302: And Phibbus' car
# 303: Shall shine from far
# 304: And make and mar
# 305: The foolish Fates.
# 306: This was lofty! Now name the rest of the players.
# 307: This is Ercles' vein, a tyrant's vein; a lover is
# 308: more condoling.
# 309: Francis FLUTE, the bellows-mender.
# 310: Here, Peter QUINCE.
# 311: FLUTE, you must take Thisby on you.
# 312: What is Thisby? a wandering knight?
# 313: It is the lady that Pyramus must love.
# 314: Nay, faith, let me not play a woman; I have a beard coming.
# 315: That's all one: you shall play it in a mask, and
# 316: you may speak as small as you will.
# 317: An I may hide my face, let me play Thisby too, I'll
# 318: speak in a monstrous little voice. 'Thisne,
# 319: Thisne;' 'Ah, Pyramus, lover dear! thy Thisby dear,
# 320: and lady dear!'
# 321: No, no; you must play Pyramus: and, FLUTE, you Thisby.
# 322: Well, proceed.
# 323: Robin STARVELING, the tailor.
# 324: Here, Peter QUINCE.
# 325: Robin STARVELING, you must play Thisby's mother.
# 326: Tom SNOUT, the tinker.
# 327: Here, Peter QUINCE.
# 328: You, Pyramus' father: myself, Thisby's father:
# 329: SNUG, the joiner; you, the lion's part: and, I
# 330: hope, here is a play fitted.
# 331: Have you the lion's part written? pray you, if it
# 332: be, give it me, for I am slow of study.
# 333: You may do it extempore, for it is nothing but roaring.
# 334: Let me play the lion too: I will roar, that I will
# 335: do any man's heart good to hear me; I will roar,
# 336: that I will make the duke say 'Let him roar again,
# 337: let him roar again.'
# 338: An you should do it too terribly, you would fright
# 339: the duchess and the ladies, that they would shriek;
# 340: and that were enough to hang us all.
# 341: ALL
# 342: That would hang us, every mother's son.
# 343: I grant you, friends, if that you should fright the
# 344: ladies out of their wits, they would have no more
# 345: discretion but to hang us: but I will aggravate my
# 346: voice so that I will roar you as gently as any
# 347: sucking dove; I will roar you an 'twere any
# 348: nightingale.
# 349: You can play no part but Pyramus; for Pyramus is a
# 350: sweet-faced man; a proper man, as one shall see in a
# 351: summer's day; a most lovely gentleman-like man:
# 352: therefore you must needs play Pyramus.
# 353: Well, I will undertake it. What beard were I best
# 354: to play it in?
# 355: Why, what you will.
# 356: I will discharge it in either your straw-colour
# 357: beard, your orange-tawny beard, your purple-in-grain
# 358: beard, or your French-crown-colour beard, your
# 359: perfect yellow.
# 360: Some of your French crowns have no hair at all, and
# 361: then you will play bare-faced. But, masters, here
# 362: are your parts: and I am to entreat you, request
# 363: you and desire you, to con them by to-morrow night;
# 364: and meet me in the palace wood, a mile without the
# 365: town, by moonlight; there will we rehearse, for if
# 366: we meet in the city, we shall be dogged with
# 367: company, and our devices known. In the meantime I
# 368: will draw a bill of properties, such as our play
# 369: wants. I pray you, fail me not.
# 370: We will meet; and there we may rehearse most
# 371: obscenely and courageously. Take pains; be perfect: adieu.
# 372: At the duke's oak we meet.
# 373: Enough; hold or cut bow-strings.
# 374: Exeunt
# 375:
# 378:
# 380: How now, spirit! whither wander you?
# 381: Fairy
# 382: Over hill, over dale,
# 383: Thorough bush, thorough brier,
# 384: Over park, over pale,
# 385: Thorough flood, thorough fire,
# 386: I do wander everywhere,
# 387: Swifter than the moon's sphere;
# 388: And I serve the fairy queen,
# 389: To dew her orbs upon the green.
# 390: The cowslips tall her pensioners be:
# 391: In their gold coats spots you see;
# 392: Those be rubies, fairy favours,
# 393: In those freckles live their savours:
# 394: I must go seek some dewdrops here
# 395: And hang a pearl in every cowslip's ear.
# 396: Farewell, thou lob of spirits; I'll be gone:
# 397: Our queen and all our elves come here anon.
# 398: The king doth keep his revels here to-night:
# 399: Take heed the queen come not within his sight;
# 400: For OBERON is passing fell and wrath,
# 401: Because that she as her attendant hath
# 402: A lovely boy, stolen from an Indian king;
# 403: She never had so sweet a changeling;
# 404: And jealous OBERON would have the child
# 405: Knight of his train, to trace the forests wild;
# 406: But she perforce withholds the loved boy,
# 407: Crowns him with flowers and makes him all her joy:
# 408: And now they never meet in grove or green,
# 409: By fountain clear, or spangled starlight sheen,
# 410: But, they do square, that all their elves for fear
# 411: Creep into acorn-cups and hide them there.
# 412: Fairy
# 413: Either I mistake your shape and making quite,
# 414: Or else you are that shrewd and knavish sprite
# 415: Call'd Robin Goodfellow: are not you he
# 416: That frights the maidens of the villagery;
# 417: Skim milk, and sometimes labour in the quern
# 418: And bootless make the breathless housewife churn;
# 419: And sometime make the drink to bear no barm;
# 420: Mislead night-wanderers, laughing at their harm?
# 421: Those that Hobgoblin call you and sweet PUCK,
# 422: You do their work, and they shall have good luck:
# 423: Are not you he?
# 424: Thou speak'st aright;
# 425: I am that merry wanderer of the night.
# 426: I jest to OBERON and make him smile
# 427: When I a fat and bean-fed horse beguile,
# 428: Neighing in likeness of a filly foal:
# 429: And sometime lurk I in a gossip's bowl,
# 430: In very likeness of a roasted crab,
# 431: And when she drinks, against her lips I bob
# 432: And on her wither'd dewlap pour the ale.
# 433: The wisest aunt, telling the saddest tale,
# 434: Sometime for three-foot stool mistaketh me;
# 435: Then slip I from her bum, down topples she,
# 436: And 'tailor' cries, and falls into a cough;
# 437: And then the whole quire hold their hips and laugh,
# 438: And waxen in their mirth and neeze and swear
# 439: A merrier hour was never wasted there.
# 440: But, room, fairy! here comes OBERON.
# 441: Fairy
# 442: And here my mistress. Would that he were gone!
# 444: Ill met by moonlight, proud TITANIA.
# 445: What, jealous OBERON! Fairies, skip hence:
# 446: I have forsworn his bed and company.
# 447: Tarry, rash wanton: am not I thy lord?
# 448: Then I must be thy lady: but I know
# 449: When thou hast stolen away from fairy land,
# 450: And in the shape of Corin sat all day,
# 451: Playing on pipes of corn and versing love
# 452: To amorous Phillida. Why art thou here,
# 453: Come from the farthest Steppe of India?
# 454: But that, forsooth, the bouncing Amazon,
# 455: Your buskin'd mistress and your warrior love,
# 456: To THESEUS must be wedded, and you come
# 457: To give their bed joy and prosperity.
# 458: How canst thou thus for shame, TITANIA,
# 459: Glance at my credit with HIPPOLYTA,
# 460: Knowing I know thy love to THESEUS?
# 461: Didst thou not lead him through the glimmering night
# 462: From Perigenia, whom he ravished?
# 463: And make him with fair AEgle break his faith,
# 464: With Ariadne and Antiopa?
# 465: These are the forgeries of jealousy:
# 466: And never, since the middle summer's spring,
# 467: Met we on hill, in dale, forest or mead,
# 468: By paved fountain or by rushy brook,
# 469: Or in the beached margent of the sea,
# 470: To dance our ringlets to the whistling wind,
# 471: But with thy brawls thou hast disturb'd our sport.
# 472: Therefore the winds, piping to us in vain,
# 473: As in revenge, have suck'd up from the sea
# 474: Contagious fogs; which falling in the land
# 475: Have every pelting river made so proud
# 476: That they have overborne their continents:
# 477: The ox hath therefore stretch'd his yoke in vain,
# 478: The ploughman lost his sweat, and the green corn
# 479: Hath rotted ere his youth attain'd a beard;
# 480: The fold stands empty in the drowned field,
# 481: And crows are fatted with the murrion flock;
# 482: The nine men's morris is fill'd up with mud,
# 483: And the quaint mazes in the wanton green
# 484: For lack of tread are undistinguishable:
# 485: The human mortals want their winter here;
# 486: No night is now with hymn or carol blest:
# 487: Therefore the moon, the governess of floods,
# 488: Pale in her anger, washes all the air,
# 489: That rheumatic diseases do abound:
# 490: And thorough this distemperature we see
# 491: The seasons alter: hoary-headed frosts
# 492: Far in the fresh lap of the crimson rose,
# 493: And on old Hiems' thin and icy crown
# 494: An odorous chaplet of sweet summer buds
# 495: Is, as in mockery, set: the spring, the summer,
# 496: The childing autumn, angry winter, change
# 497: Their wonted liveries, and the mazed world,
# 498: By their increase, now knows not which is which:
# 499: And this same progeny of evils comes
# 500: From our debate, from our dissension;
# 501: We are their parents and original.
# 502: Do you amend it then; it lies in you:
# 503: Why should TITANIA cross her OBERON?
# 504: I do but beg a little changeling boy,
# 505: To be my henchman.
# 506: Set your heart at rest:
# 507: The fairy land buys not the child of me.
# 508: His mother was a votaress of my order:
# 509: And, in the spiced Indian air, by night,
# 510: Full often hath she gossip'd by my side,
# 511: And sat with me on Neptune's yellow sands,
# 512: Marking the embarked traders on the flood,
# 513: When we have laugh'd to see the sails conceive
# 514: And grow big-bellied with the wanton wind;
# 515: Which she, with pretty and with swimming gait
# 516: Following,--her womb then rich with my young squire,--
# 517: Would imitate, and sail upon the land,
# 518: To fetch me trifles, and return again,
# 519: As from a voyage, rich with merchandise.
# 520: But she, being mortal, of that boy did die;
# 521: And for her sake do I rear up her boy,
# 522: And for her sake I will not part with him.
# 523: How long within this wood intend you stay?
# 524: Perchance till after THESEUS' wedding-day.
# 525: If you will patiently dance in our round
# 526: And see our moonlight revels, go with us;
# 527: If not, shun me, and I will spare your haunts.
# 528: Give me that boy, and I will go with thee.
# 529: Not for thy fairy kingdom. Fairies, away!
# 530: We shall chide downright, if I longer stay.
# 532: Well, go thy way: thou shalt not from this grove
# 533: Till I torment thee for this injury.
# 534: My gentle PUCK, come hither. Thou rememberest
# 535: Since once I sat upon a promontory,
# 536: And heard a mermaid on a dolphin's back
# 537: Uttering such dulcet and harmonious breath
# 538: That the rude sea grew civil at her song
# 539: And certain stars shot madly from their spheres,
# 540: To hear the sea-maid's music.
# 541: I remember.
# 542: That very time I saw, but thou couldst not,
# 543: Flying between the cold moon and the earth,
# 544: Cupid all arm'd: a certain aim he took
# 545: At a fair vestal throned by the west,
# 546: And loosed his love-shaft smartly from his bow,
# 547: As it should pierce a hundred thousand hearts;
# 548: But I might see young Cupid's fiery shaft
# 549: Quench'd in the chaste beams of the watery moon,
# 550: And the imperial votaress passed on,
# 551: In maiden meditation, fancy-free.
# 552: Yet mark'd I where the bolt of Cupid fell:
# 553: It fell upon a little western flower,
# 554: Before milk-white, now purple with love's wound,
# 555: And maidens call it love-in-idleness.
# 556: Fetch me that flower; the herb I shew'd thee once:
# 557: The juice of it on sleeping eye-lids laid
# 558: Will make or man or woman madly dote
# 559: Upon the next live creature that it sees.
# 560: Fetch me this herb; and be thou here again
# 561: Ere the leviathan can swim a league.
# 562: I'll put a girdle round about the earth
# 563: In forty minutes.
# 565: Having once this juice,
# 566: I'll watch TITANIA when she is asleep,
# 567: And drop the liquor of it in her eyes.
# 568: The next thing then she waking looks upon,
# 569: Be it on lion, bear, or wolf, or bull,
# 570: On meddling monkey, or on busy ape,
# 571: She shall pursue it with the soul of love:
# 572: And ere I take this charm from off her sight,
# 573: As I can take it with another herb,
# 574: I'll make her render up her page to me.
# 575: But who comes here? I am invisible;
# 576: And I will overhear their conference.
# 578: I love thee not, therefore pursue me not.
# 579: Where is LYSANDER and fair HERMIA?
# 580: The one I'll slay, the other slayeth me.
# 581: Thou told'st me they were stolen unto this wood;
# 582: And here am I, and wode within this wood,
# 583: Because I cannot meet my HERMIA.
# 584: Hence, get thee gone, and follow me no more.
# 585: You draw me, you hard-hearted adamant;
# 586: But yet you draw not iron, for my heart
# 587: Is true as steel: leave you your power to draw,
# 588: And I shall have no power to follow you.
# 589: Do I entice you? do I speak you fair?
# 590: Or, rather, do I not in plainest truth
# 591: Tell you, I do not, nor I cannot love you?
# 592: And even for that do I love you the more.
# 593: I am your spaniel; and, DEMETRIUS,
# 594: The more you beat me, I will fawn on you:
# 595: Use me but as your spaniel, spurn me, strike me,
# 596: Neglect me, lose me; only give me leave,
# 597: Unworthy as I am, to follow you.
# 598: What worser place can I beg in your love,--
# 599: And yet a place of high respect with me,--
# 600: Than to be used as you use your dog?
# 601: Tempt not too much the hatred of my spirit;
# 602: For I am sick when I do look on thee.
# 603: And I am sick when I look not on you.
# 604: You do impeach your modesty too much,
# 605: To leave the city and commit yourself
# 606: Into the hands of one that loves you not;
# 607: To trust the opportunity of night
# 608: And the ill counsel of a desert place
# 609: With the rich worth of your virginity.
# 610: Your virtue is my privilege: for that
# 611: It is not night when I do see your face,
# 612: Therefore I think I am not in the night;
# 613: Nor doth this wood lack worlds of company,
# 614: For you in my respect are all the world:
# 615: Then how can it be said I am alone,
# 616: When all the world is here to look on me?
# 617: I'll run from thee and hide me in the brakes,
# 618: And leave thee to the mercy of wild beasts.
# 619: The wildest hath not such a heart as you.
# 620: Run when you will, the story shall be changed:
# 621: Apollo flies, and Daphne holds the chase;
# 622: The dove pursues the griffin; the mild hind
# 623: Makes speed to catch the tiger; bootless speed,
# 624: When cowardice pursues and valour flies.
# 625: I will not stay thy questions; let me go:
# 626: Or, if thou follow me, do not believe
# 627: But I shall do thee mischief in the wood.
# 628: Ay, in the temple, in the town, the field,
# 629: You do me mischief. Fie, DEMETRIUS!
# 630: Your wrongs do set a scandal on my sex:
# 631: We cannot fight for love, as men may do;
# 632: We should be wood and were not made to woo.
# 634: I'll follow thee and make a heaven of hell,
# 635: To die upon the hand I love so well.
# 637: Fare thee well, nymph: ere he do leave this grove,
# 638: Thou shalt fly him and he shall seek thy love.
# 639: Re-enter PUCK
# 640: Hast thou the flower there? Welcome, wanderer.
# 641: Ay, there it is.
# 642: I pray thee, give it me.
# 643: I know a bank where the wild thyme blows,
# 644: Where oxlips and the nodding violet grows,
# 645: Quite over-canopied with luscious woodbine,
# 646: With sweet musk-roses and with eglantine:
# 647: There sleeps TITANIA sometime of the night,
# 648: Lull'd in these flowers with dances and delight;
# 649: And there the snake throws her enamell'd skin,
# 650: Weed wide enough to wrap a fairy in:
# 651: And with the juice of this I'll streak her eyes,
# 652: And make her full of hateful fantasies.
# 653: Take thou some of it, and seek through this grove:
# 654: A sweet Athenian lady is in love
# 655: With a disdainful youth: anoint his eyes;
# 656: But do it when the next thing he espies
# 657: May be the lady: thou shalt know the man
# 658: By the Athenian garments he hath on.
# 659: Effect it with some care, that he may prove
# 660: More fond on her than she upon her love:
# 661: And look thou meet me ere the first cock crow.
# 662: Fear not, my lord, your servant shall do so.
# 663: Exeunt
# 665:
# 667: Come, now a roundel and a fairy song;
# 668: Then, for the third part of a minute, hence;
# 669: Some to kill cankers in the musk-rose buds,
# 670: Some war with rere-mice for their leathern wings,
# 671: To make my small elves coats, and some keep back
# 672: The clamorous owl that nightly hoots and wonders
# 673: At our quaint spirits. Sing me now asleep;
# 674: Then to your offices and let me rest.
# 675: The Fairies sing
# 676: You spotted snakes with double tongue,
# 677: Thorny hedgehogs, be not seen;
# 678: Newts and blind-worms, do no wrong,
# 679: Come not near our fairy queen.
# 680: Philomel, with melody
# 681: Sing in our sweet lullaby;
# 682: Lulla, lulla, lullaby, lulla, lulla, lullaby:
# 683: Never harm,
# 684: Nor spell nor charm,
# 685: Come our lovely lady nigh;
# 686: So, good night, with lullaby.
# 687: Weaving spiders, come not here;
# 688: Hence, you long-legg'd spinners, hence!
# 689: Beetles black, approach not near;
# 690: Worm nor snail, do no offence.
# 691: Philomel, with melody, & c.
# 692: Fairy
# 693: Hence, away! now all is well:
# 694: One aloof stand sentinel.
# 695: Exeunt Fairies. TITANIA sleeps
# 697: What thou seest when thou dost wake,
# 698: Do it for thy true-love take,
# 699: Love and languish for his sake:
# 700: Be it ounce, or cat, or bear,
# 701: Pard, or boar with bristled hair,
# 702: In thy eye that shall appear
# 703: When thou wakest, it is thy dear:
# 704: Wake when some vile thing is near.
# 707: Fair love, you faint with wandering in the wood;
# 708: And to speak troth, I have forgot our way:
# 709: We'll rest us, HERMIA, if you think it good,
# 710: And tarry for the comfort of the day.
# 711: Be it so, LYSANDER: find you out a bed;
# 712: For I upon this bank will rest my head.
# 713: One turf shall serve as pillow for us both;
# 714: One heart, one bed, two bosoms and one troth.
# 715: Nay, good LYSANDER; for my sake, my dear,
# 716: Lie further off yet, do not lie so near.
# 717: O, take the sense, sweet, of my innocence!
# 718: Love takes the meaning in love's conference.
# 719: I mean, that my heart unto yours is knit
# 720: So that but one heart we can make of it;
# 721: Two bosoms interchained with an oath;
# 722: So then two bosoms and a single troth.
# 723: Then by your side no bed-room me deny;
# 724: For lying so, HERMIA, I do not lie.
# 725: LYSANDER riddles very prettily:
# 726: Now much beshrew my manners and my pride,
# 727: If HERMIA meant to say LYSANDER lied.
# 728: But, gentle friend, for love and courtesy
# 729: Lie further off; in human modesty,
# 730: Such separation as may well be said
# 731: Becomes a virtuous bachelor and a maid,
# 732: So far be distant; and, good night, sweet friend:
# 733: Thy love ne'er alter till thy sweet life end!
# 734: Amen, amen, to that fair prayer, say I;
# 735: And then end life when I end loyalty!
# 736: Here is my bed: sleep give thee all his rest!
# 737: With half that wish the wisher's eyes be press'd!
# 738: They sleep
# 740: Through the forest have I gone.
# 741: But Athenian found I none,
# 742: On whose eyes I might approve
# 743: This flower's force in stirring love.
# 744: Night and silence.--Who is here?
# 745: Weeds of Athens he doth wear:
# 746: This is he, my master said,
# 747: Despised the Athenian maid;
# 748: And here the maiden, sleeping sound,
# 749: On the dank and dirty ground.
# 750: Pretty soul! she durst not lie
# 751: Near this lack-love, this kill-courtesy.
# 752: Churl, upon thy eyes I throw
# 753: All the power this charm doth owe.
# 754: When thou wakest, let love forbid
# 755: Sleep his seat on thy eyelid:
# 756: So awake when I am gone;
# 757: For I must now to OBERON.
# 760: Stay, though thou kill me, sweet DEMETRIUS.
# 761: I charge thee, hence, and do not haunt me thus.
# 762: O, wilt thou darkling leave me? do not so.
# 763: Stay, on thy peril: I alone will go.
# 765: O, I am out of breath in this fond chase!
# 766: The more my prayer, the lesser is my grace.
# 767: Happy is HERMIA, wheresoe'er she lies;
# 768: For she hath blessed and attractive eyes.
# 769: How came her eyes so bright? Not with salt tears:
# 770: If so, my eyes are oftener wash'd than hers.
# 771: No, no, I am as ugly as a bear;
# 772: For beasts that meet me run away for fear:
# 773: Therefore no marvel though DEMETRIUS
# 774: Do, as a monster fly my presence thus.
# 775: What wicked and dissembling glass of mine
# 776: Made me compare with HERMIA's sphery eyne?
# 777: But who is here? LYSANDER! on the ground!
# 778: Dead? or asleep? I see no blood, no wound.
# 779: LYSANDER if you live, good sir, awake.
# 780: [Awaking] And run through fire I will for thy sweet sake.
# 781: Transparent HELENA! Nature shows art,
# 782: That through thy bosom makes me see thy heart.
# 783: Where is DEMETRIUS? O, how fit a word
# 784: Is that vile name to perish on my sword!
# 785: Do not say so, LYSANDER; say not so
# 786: What though he love your HERMIA? Lord, what though?
# 787: Yet HERMIA still loves you: then be content.
# 788: Content with HERMIA! No; I do repent
# 789: The tedious minutes I with her have spent.
# 790: Not HERMIA but HELENA I love:
# 791: Who will not change a raven for a dove?
# 792: The will of man is by his reason sway'd;
# 793: And reason says you are the worthier maid.
# 794: Things growing are not ripe until their season
# 795: So I, being young, till now ripe not to reason;
# 796: And touching now the point of human skill,
# 797: Reason becomes the marshal to my will
# 798: And leads me to your eyes, where I o'erlook
# 799: Love's stories written in love's richest book.
# 800: Wherefore was I to this keen mockery born?
# 801: When at your hands did I deserve this scorn?
# 802: Is't not enough, is't not enough, young man,
# 803: That I did never, no, nor never can,
# 804: Deserve a sweet look from DEMETRIUS' eye,
# 805: But you must flout my insufficiency?
# 806: Good troth, you do me wrong, good sooth, you do,
# 807: In such disdainful manner me to woo.
# 808: But fare you well: perforce I must confess
# 809: I thought you lord of more true gentleness.
# 810: O, that a lady, of one man refused.
# 811: Should of another therefore be abused!
# 813: She sees not HERMIA. HERMIA, sleep thou there:
# 814: And never mayst thou come LYSANDER near!
# 815: For as a surfeit of the sweetest things
# 816: The deepest loathing to the stomach brings,
# 817: Or as tie heresies that men do leave
# 818: Are hated most of those they did deceive,
# 819: So thou, my surfeit and my heresy,
# 820: Of all be hated, but the most of me!
# 821: And, all my powers, address your love and might
# 822: To honour Helen and to be her knight!
# 824: [Awaking] Help me, LYSANDER, help me! do thy best
# 825: To pluck this crawling serpent from my breast!
# 826: Ay me, for pity! what a dream was here!
# 827: LYSANDER, look how I do quake with fear:
# 828: Methought a serpent eat my heart away,
# 829: And you sat smiling at his cruel pray.
# 830: LYSANDER! what, removed? LYSANDER! lord!
# 831: What, out of hearing? gone? no sound, no word?
# 832: Alack, where are you speak, an if you hear;
# 833: Speak, of all loves! I swoon almost with fear.
# 834: No? then I well perceive you all not nigh
# 835: Either death or you I'll find immediately.
# 837:
# 840:
# 842: Are we all met?
# 843: Pat, pat; and here's a marvellous convenient place
# 844: for our rehearsal. This green plot shall be our
# 845: stage, this hawthorn-brake our tiring-house; and we
# 846: will do it in action as we will do it before the duke.
# 847: Peter QUINCE,--
# 848: What sayest thou, bully BOTTOM?
# 849: There are things in this comedy of Pyramus and
# 850: Thisby that will never please. First, Pyramus must
# 851: draw a sword to kill himself; which the ladies
# 852: cannot abide. How answer you that?
# 853: By'r lakin, a parlous fear.
# 854: I believe we must leave the killing out, when all is done.
# 855: Not a whit: I have a device to make all well.
# 856: Write me a prologue; and let the prologue seem to
# 857: say, we will do no harm with our swords, and that
# 858: Pyramus is not killed indeed; and, for the more
# 859: better assurance, tell them that I, Pyramus, am not
# 860: Pyramus, but BOTTOM the weaver: this will put them
# 861: out of fear.
# 862: Well, we will have such a prologue; and it shall be
# 863: written in eight and six.
# 864: No, make it two more; let it be written in eight and eight.
# 865: Will not the ladies be afeard of the lion?
# 866: I fear it, I promise you.
# 867: Masters, you ought to consider with yourselves: to
# 868: bring in--God shield us!--a lion among ladies, is a
# 869: most dreadful thing; for there is not a more fearful
# 870: wild-fowl than your lion living; and we ought to
# 871: look to 't.
# 872: Therefore another prologue must tell he is not a lion.
# 873: Nay, you must name his name, and half his face must
# 874: be seen through the lion's neck: and he himself
# 875: must speak through, saying thus, or to the same
# 876: defect,--'Ladies,'--or 'Fair-ladies--I would wish
# 877: You,'--or 'I would request you,'--or 'I would
# 878: entreat you,--not to fear, not to tremble: my life
# 879: for yours. If you think I come hither as a lion, it
# 880: were pity of my life: no I am no such thing; I am a
# 881: man as other men are;' and there indeed let him name
# 882: his name, and tell them plainly he is SNUG the joiner.
# 883: Well it shall be so. But there is two hard things;
# 884: that is, to bring the moonlight into a chamber; for,
# 885: you know, Pyramus and Thisby meet by moonlight.
# 886: Doth the moon shine that night we play our play?
# 887: A calendar, a calendar! look in the almanac; find
# 888: out moonshine, find out moonshine.
# 889: Yes, it doth shine that night.
# 890: Why, then may you leave a casement of the great
# 891: chamber window, where we play, open, and the moon
# 892: may shine in at the casement.
# 893: Ay; or else one must come in with a bush of thorns
# 894: and a lanthorn, and say he comes to disfigure, or to
# 895: present, the person of Moonshine. Then, there is
# 896: another thing: we must have a wall in the great
# 897: chamber; for Pyramus and Thisby says the story, did
# 898: talk through the chink of a wall.
# 899: You can never bring in a wall. What say you, BOTTOM?
# 900: Some man or other must present Wall: and let him
# 901: have some plaster, or some loam, or some rough-cast
# 902: about him, to signify wall; and let him hold his
# 903: fingers thus, and through that cranny shall Pyramus
# 904: and Thisby whisper.
# 905: If that may be, then all is well. Come, sit down,
# 906: every mother's son, and rehearse your parts.
# 907: Pyramus, you begin: when you have spoken your
# 908: speech, enter into that brake: and so every one
# 909: according to his cue.
# 911: What hempen home-spuns have we swaggering here,
# 912: So near the cradle of the fairy queen?
# 913: What, a play toward! I'll be an auditor;
# 914: An actor too, perhaps, if I see cause.
# 915: Speak, Pyramus. Thisby, stand forth.
# 916: Thisby, the flowers of odious savours sweet,--
# 917: Odours, odours.
# 918: --odours savours sweet:
# 919: So hath thy breath, my dearest Thisby dear.
# 920: But hark, a voice! stay thou but here awhile,
# 921: And by and by I will to thee appear.
# 923: A stranger Pyramus than e'er played here.
# 925: Must I speak now?
# 926: Ay, marry, must you; for you must understand he goes
# 927: but to see a noise that he heard, and is to come again.
# 928: Most radiant Pyramus, most lily-white of hue,
# 929: Of colour like the red rose on triumphant brier,
# 930: Most brisky juvenal and eke most lovely Jew,
# 931: As true as truest horse that yet would never tire,
# 932: I'll meet thee, Pyramus, at Ninny's tomb.
# 933: 'Ninus' tomb,' man: why, you must not speak that
# 934: yet; that you answer to Pyramus: you speak all your
# 935: part at once, cues and all Pyramus enter: your cue
# 936: is past; it is, 'never tire.'
# 937: O,--As true as truest horse, that yet would
# 938: never tire.
# 939: Re-enter PUCK, and BOTTOM with an ass's head
# 940: If I were fair, Thisby, I were only thine.
# 941: O monstrous! O strange! we are haunted. Pray,
# 942: masters! fly, masters! Help!
# 943: Exeunt QUINCE, SNUG, FLUTE, SNOUT, and STARVELING
# 944: I'll follow you, I'll lead you about a round,
# 945: Through bog, through bush, through brake, through brier:
# 946: Sometime a horse I'll be, sometime a hound,
# 947: A hog, a headless bear, sometime a fire;
# 948: And neigh, and bark, and grunt, and roar, and burn,
# 949: Like horse, hound, hog, bear, fire, at every turn.
# 951: Why do they run away? this is a knavery of them to
# 952: make me afeard.
# 953: Re-enter SNOUT
# 954: O BOTTOM, thou art changed! what do I see on thee?
# 955: What do you see? you see an asshead of your own, do
# 956: you?
# 958: Re-enter QUINCE
# 959: Bless thee, BOTTOM! bless thee! thou art
# 960: translated.
# 962: I see their knavery: this is to make an ass of me;
# 963: to fright me, if they could. But I will not stir
# 964: from this place, do what they can: I will walk up
# 965: and down here, and I will sing, that they shall hear
# 966: I am not afraid.
# 967: Sings
# 968: The ousel cock so black of hue,
# 969: With orange-tawny bill,
# 970: The throstle with his note so true,
# 971: The wren with little quill,--
# 972: [Awaking] What angel wakes me from my flowery bed?
# 973: [Sings]
# 974: The finch, the sparrow and the lark,
# 975: The plain-song cuckoo gray,
# 976: Whose note full many a man doth mark,
# 977: And dares not answer nay;--
# 978: for, indeed, who would set his wit to so foolish
# 979: a bird? who would give a bird the lie, though he cry
# 980: 'cuckoo' never so?
# 981: I pray thee, gentle mortal, sing again:
# 982: Mine ear is much enamour'd of thy note;
# 983: So is mine eye enthralled to thy shape;
# 984: And thy fair virtue's force perforce doth move me
# 985: On the first view to say, to swear, I love thee.
# 986: Methinks, mistress, you should have little reason
# 987: for that: and yet, to say the truth, reason and
# 988: love keep little company together now-a-days; the
# 989: more the pity that some honest neighbours will not
# 990: make them friends. Nay, I can gleek upon occasion.
# 991: Thou art as wise as thou art beautiful.
# 992: Not so, neither: but if I had wit enough to get out
# 993: of this wood, I have enough to serve mine own turn.
# 994: Out of this wood do not desire to go:
# 995: Thou shalt remain here, whether thou wilt or no.
# 996: I am a spirit of no common rate;
# 997: The summer still doth tend upon my state;
# 998: And I do love thee: therefore, go with me;
# 999: I'll give thee fairies to attend on thee,
# 1000: And they shall fetch thee jewels from the deep,
# 1001: And sing while thou on pressed flowers dost sleep;
# 1002: And I will purge thy mortal grossness so
# 1003: That thou shalt like an airy spirit go.
# 1004: PEASEBLOSSOM! COBWEB! MOTH! and MUSTARDSEED!
# 1006: Ready.
# 1007: And I.
# 1008: And I.
# 1009: And I.
# 1010: ALL
# 1011: Where shall we go?
# 1012: Be kind and courteous to this gentleman;
# 1013: Hop in his walks and gambol in his eyes;
# 1014: Feed him with apricocks and dewberries,
# 1015: With purple grapes, green figs, and mulberries;
# 1016: The honey-bags steal from the humble-bees,
# 1017: And for night-tapers crop their waxen thighs
# 1018: And light them at the fiery glow-worm's eyes,
# 1019: To have my love to bed and to arise;
# 1020: And pluck the wings from Painted butterflies
# 1021: To fan the moonbeams from his sleeping eyes:
# 1022: Nod to him, elves, and do him courtesies.
# 1023: Hail, mortal!
# 1024: Hail!
# 1025: Hail!
# 1026: Hail!
# 1027: I cry your worship's mercy, heartily: I beseech your
# 1028: worship's name.
# 1029: COBWEB.
# 1030: I shall desire you of more acquaintance, good Master
# 1031: COBWEB: if I cut my finger, I shall make bold with
# 1032: you. Your name, honest gentleman?
# 1033: PEASEBLOSSOM.
# 1034: I pray you, commend me to Mistress Squash, your
# 1035: mother, and to Master Peascod, your father. Good
# 1036: Master PEASEBLOSSOM, I shall desire you of more
# 1037: acquaintance too. Your name, I beseech you, sir?
# 1038: MUSTARDSEED.
# 1039: Good Master MUSTARDSEED, I know your patience well:
# 1040: that same cowardly, giant-like ox-beef hath
# 1041: devoured many a gentleman of your house: I promise
# 1042: you your kindred had made my eyes water ere now. I
# 1043: desire your more acquaintance, good Master
# 1044: MUSTARDSEED.
# 1045: Come, wait upon him; lead him to my bower.
# 1046: The moon methinks looks with a watery eye;
# 1047: And when she weeps, weeps every little flower,
# 1048: Lamenting some enforced chastity.
# 1049: Tie up my love's tongue bring him silently.
# 1050: Exeunt
# 1052:
# 1054: I wonder if TITANIA be awaked;
# 1055: Then, what it was that next came in her eye,
# 1056: Which she must dote on in extremity.
# 1058: Here comes my messenger.
# 1059: How now, mad spirit!
# 1060: What night-rule now about this haunted grove?
# 1061: My mistress with a monster is in love.
# 1062: Near to her close and consecrated bower,
# 1063: While she was in her dull and sleeping hour,
# 1064: A crew of patches, rude mechanicals,
# 1065: That work for bread upon Athenian stalls,
# 1066: Were met together to rehearse a play
# 1067: Intended for great THESEUS' nuptial-day.
# 1068: The shallowest thick-skin of that barren sort,
# 1069: Who Pyramus presented, in their sport
# 1070: Forsook his scene and enter'd in a brake
# 1071: When I did him at this advantage take,
# 1072: An ass's nole I fixed on his head:
# 1073: Anon his Thisbe must be answered,
# 1074: And forth my mimic comes. When they him spy,
# 1075: As wild geese that the creeping fowler eye,
# 1076: Or russet-pated choughs, many in sort,
# 1077: Rising and cawing at the gun's report,
# 1078: Sever themselves and madly sweep the sky,
# 1079: So, at his sight, away his fellows fly;
# 1080: And, at our stamp, here o'er and o'er one falls;
# 1081: He murder cries and help from Athens calls.
# 1082: Their sense thus weak, lost with their fears
# 1083: thus strong,
# 1084: Made senseless things begin to do them wrong;
# 1085: For briers and thorns at their apparel snatch;
# 1086: Some sleeves, some hats, from yielders all
# 1087: things catch.
# 1088: I led them on in this distracted fear,
# 1089: And left sweet Pyramus translated there:
# 1090: When in that moment, so it came to pass,
# 1091: TITANIA waked and straightway loved an ass.
# 1092: This falls out better than I could devise.
# 1093: But hast thou yet latch'd the Athenian's eyes
# 1094: With the love-juice, as I did bid thee do?
# 1095: I took him sleeping,--that is finish'd too,--
# 1096: And the Athenian woman by his side:
# 1097: That, when he waked, of force she must be eyed.
# 1099: Stand close: this is the same Athenian.
# 1100: This is the woman, but not this the man.
# 1101: O, why rebuke you him that loves you so?
# 1102: Lay breath so bitter on your bitter foe.
# 1103: Now I but chide; but I should use thee worse,
# 1104: For thou, I fear, hast given me cause to curse,
# 1105: If thou hast slain LYSANDER in his sleep,
# 1106: Being o'er shoes in blood, plunge in the deep,
# 1107: And kill me too.
# 1108: The sun was not so true unto the day
# 1109: As he to me: would he have stolen away
# 1110: From sleeping HERMIA? I'll believe as soon
# 1111: This whole earth may be bored and that the moon
# 1112: May through the centre creep and so displease
# 1113: Her brother's noontide with Antipodes.
# 1114: It cannot be but thou hast murder'd him;
# 1115: So should a murderer look, so dead, so grim.
# 1116: So should the murder'd look, and so should I,
# 1117: Pierced through the heart with your stern cruelty:
# 1118: Yet you, the murderer, look as bright, as clear,
# 1119: As yonder Venus in her glimmering sphere.
# 1120: What's this to my LYSANDER? where is he?
# 1121: Ah, good DEMETRIUS, wilt thou give him me?
# ...
# 1942: And now have toil'd their unbreathed memories
# 1943: With this same play, against your nuptial.
# 1944: And we will hear it.
# 1945: No, my noble lord;
# 1946: It is not for you: I have heard it over,
# 1947: And it is nothing, nothing in the world;
# 1948: Unless you can find sport in their intents,
# 1949: Extremely stretch'd and conn'd with cruel pain,
# 1950: To do you service.
# 1951: I will hear that play;
# 1952: For never anything can be amiss,
# 1953: When simpleness and duty tender it.
# 1954: Go, bring them in: and take your places, ladies.
# 1956: I love not to see wretchedness o'er charged
# 1957: And duty in his service perishing.
# 1958: Why, gentle sweet, you shall see no such thing.
# 1959: He says they can do nothing in this kind.
# 1960: The kinder we, to give them thanks for nothing.
# 1961: Our sport shall be to take what they mistake:
# 1962: And what poor duty cannot do, noble respect
# 1963: Takes it in might, not merit.
# 1964: Where I have come, great clerks have purposed
# 1965: To greet me with premeditated welcomes;
# 1966: Where I have seen them shiver and look pale,
# 1967: Make periods in the midst of sentences,
# 1968: Throttle their practised accent in their fears
# 1969: And in conclusion dumbly have broke off,
# 1970: Not paying me a welcome. Trust me, sweet,
# 1971: Out of this silence yet I pick'd a welcome;
# 1972: And in the modesty of fearful duty
# 1973: I read as much as from the rattling tongue
# 1974: Of saucy and audacious eloquence.
# 1975: Love, therefore, and tongue-tied simplicity
# 1976: In least speak most, to my capacity.
# 1977: Re-enter PHILOSTRATE
# 1978: So please your grace, the Prologue is address'd.
# 1979: Let him approach.
# 1980: Flourish of trumpets
# 1982: Prologue
# 1983: If we offend, it is with our good will.
# 1984: That you should think, we come not to offend,
# 1985: But with good will. To show our simple skill,
# 1986: That is the true beginning of our end.
# 1987: Consider then we come but in despite.
# 1988: We do not come as minding to contest you,
# 1989: Our true intent is. All for your delight
# 1990: We are not here. That you should here repent you,
# 1991: The actors are at hand and by their show
# 1992: You shall know all that you are like to know.
# 1993: This fellow doth not stand upon points.
# 1994: He hath rid his prologue like a rough colt; he knows
# 1995: not the stop. A good moral, my lord: it is not
# 1996: enough to speak, but to speak true.
# 1997: Indeed he hath played on his prologue like a child
# 1998: on a recorder; a sound, but not in government.
# 1999: His speech, was like a tangled chain; nothing
# 2000: impaired, but all disordered. Who is next?
# 2002: Prologue
# 2003: Gentles, perchance you wonder at this show;
# 2004: But wonder on, till truth make all things plain.
# 2005: This man is Pyramus, if you would know;
# 2006: This beauteous lady Thisby is certain.
# 2007: This man, with lime and rough-cast, doth present
# 2008: Wall, that vile Wall which did these lovers sunder;
# 2009: And through Wall's chink, poor souls, they are content
# 2010: To whisper. At the which let no man wonder.
# 2011: This man, with lanthorn, dog, and bush of thorn,
# 2012: Presenteth Moonshine; for, if you will know,
# 2013: By moonshine did these lovers think no scorn
# 2014: To meet at Ninus' tomb, there, there to woo.
# 2015: This grisly beast, which Lion hight by name,
# 2016: The trusty Thisby, coming first by night,
# 2017: Did scare away, or rather did affright;
# 2018: And, as she fled, her mantle she did fall,
# 2019: Which Lion vile with bloody mouth did stain.
# 2020: Anon comes Pyramus, sweet youth and tall,
# 2021: And finds his trusty Thisby's mantle slain:
# 2022: Whereat, with blade, with bloody blameful blade,
# 2023: He bravely broach'd is boiling bloody breast;
# 2024: And Thisby, tarrying in mulberry shade,
# 2025: His dagger drew, and died. For all the rest,
# 2026: Let Lion, Moonshine, Wall, and lovers twain
# 2027: At large discourse, while here they do remain.
# 2028: Exeunt Prologue, Thisbe, Lion, and Moonshine
# 2029: I wonder if the lion be to speak.
# 2030: No wonder, my lord: one lion may, when many asses do.
# 2031: Wall
# 2032: In this same interlude it doth befall
# 2033: That I, one SNOUT by name, present a wall;
# 2034: And such a wall, as I would have you think,
# 2035: That had in it a crannied hole or chink,
# 2036: Through which the lovers, Pyramus and Thisby,
# 2037: Did whisper often very secretly.
# 2038: This loam, this rough-cast and this stone doth show
# 2039: That I am that same wall; the truth is so:
# 2040: And this the cranny is, right and sinister,
# 2041: Through which the fearful lovers are to whisper.
# 2042: Would you desire lime and hair to speak better?
# 2043: It is the wittiest partition that ever I heard
# 2044: discourse, my lord.
# 2046: Pyramus draws near the wall: silence!
# 2047: Pyramus
# 2048: O grim-look'd night! O night with hue so black!
# 2049: O night, which ever art when day is not!
# 2050: O night, O night! alack, alack, alack,
# 2051: I fear my Thisby's promise is forgot!
# 2052: And thou, O wall, O sweet, O lovely wall,
# 2053: That stand'st between her father's ground and mine!
# 2054: Thou wall, O wall, O sweet and lovely wall,
# 2055: Show me thy chink, to blink through with mine eyne!
# 2056: Wall holds up his fingers
# 2057: Thanks, courteous wall: Jove shield thee well for this!
# 2058: But what see I? No Thisby do I see.
# 2059: O wicked wall, through whom I see no bliss!
# 2060: Cursed be thy stones for thus deceiving me!
# 2061: The wall, methinks, being sensible, should curse again.
# 2062: Pyramus
# 2063: No, in truth, sir, he should not. 'Deceiving me'
# 2064: is Thisby's cue: she is to enter now, and I am to
# 2065: spy her through the wall. You shall see, it will
# 2066: fall pat as I told you. Yonder she comes.
# 2068: Thisbe
# 2069: O wall, full often hast thou heard my moans,
# 2070: For parting my fair Pyramus and me!
# 2071: My cherry lips have often kiss'd thy stones,
# 2072: Thy stones with lime and hair knit up in thee.
# 2073: Pyramus
# 2074: I see a voice: now will I to the chink,
# 2075: To spy an I can hear my Thisby's face. Thisby!
# 2076: Thisbe
# 2077: My love thou art, my love I think.
# 2078: Pyramus
# 2079: Think what thou wilt, I am thy lover's grace;
# 2080: And, like Limander, am I trusty still.
# 2081: Thisbe
# 2082: And I like Helen, till the Fates me kill.
# 2083: Pyramus
# 2084: Not Shafalus to Procrus was so true.
# 2085: Thisbe
# 2086: As Shafalus to Procrus, I to you.
# 2087: Pyramus
# 2088: O kiss me through the hole of this vile wall!
# 2089: Thisbe
# 2090: I kiss the wall's hole, not your lips at all.
# 2091: Pyramus
# 2092: Wilt thou at Ninny's tomb meet me straightway?
# 2093: Thisbe
# 2094: 'Tide life, 'tide death, I come without delay.
# 2095: Exeunt Pyramus and Thisbe
# 2096: Wall
# 2097: Thus have I, Wall, my part discharged so;
# 2098: And, being done, thus Wall away doth go.
# 2100: Now is the mural down between the two neighbours.
# 2101: No remedy, my lord, when walls are so wilful to hear
# 2102: without warning.
# 2103: This is the silliest stuff that ever I heard.
# 2104: The best in this kind are but shadows; and the worst
# 2105: are no worse, if imagination amend them.
# 2106: It must be your imagination then, and not theirs.
# 2107: If we imagine no worse of them than they of
# 2108: themselves, they may pass for excellent men. Here
# 2109: come two noble beasts in, a man and a lion.
# 2111: Lion
# 2112: You, ladies, you, whose gentle hearts do fear
# 2113: The smallest monstrous mouse that creeps on floor,
# 2114: May now perchance both quake and tremble here,
# 2115: When lion rough in wildest rage doth roar.
# 2116: Then know that I, one SNUG the joiner, am
# 2117: A lion-fell, nor else no lion's dam;
# 2118: For, if I should as lion come in strife
# 2119: Into this place, 'twere pity on my life.
# 2120: A very gentle beast, of a good conscience.
# 2121: The very best at a beast, my lord, that e'er I saw.
# 2122: This lion is a very fox for his valour.
# 2123: True; and a goose for his discretion.
# 2124: Not so, my lord; for his valour cannot carry his
# 2125: discretion; and the fox carries the goose.
# 2126: His discretion, I am sure, cannot carry his valour;
# 2127: for the goose carries not the fox. It is well:
# 2128: leave it to his discretion, and let us listen to the moon.
# 2129: Moonshine
# 2130: This lanthorn doth the horned moon present;--
# 2131: He should have worn the horns on his head.
# 2132: He is no crescent, and his horns are
# 2133: invisible within the circumference.
# 2134: Moonshine
# 2135: This lanthorn doth the horned moon present;
# 2136: Myself the man i' the moon do seem to be.
# 2137: This is the greatest error of all the rest: the man
# 2138: should be put into the lanthorn. How is it else the
# 2139: man i' the moon?
# 2140: He dares not come there for the candle; for, you
# 2141: see, it is already in snuff.
# 2142: I am aweary of this moon: would he would change!
# 2143: It appears, by his small light of discretion, that
# 2144: he is in the wane; but yet, in courtesy, in all
# 2145: reason, we must stay the time.
# 2146: Proceed, Moon.
# 2147: Moonshine
# 2148: All that I have to say, is, to tell you that the
# 2149: lanthorn is the moon; I, the man in the moon; this
# 2150: thorn-bush, my thorn-bush; and this dog, my dog.
# 2151: Why, all these should be in the lanthorn; for all
# 2152: these are in the moon. But, silence! here comes Thisbe.
# 2154: Thisbe
# 2155: This is old Ninny's tomb. Where is my love?
# 2156: Lion
# 2157: [Roaring] Oh--
# 2158: Thisbe runs off
# 2159: Well roared, Lion.
# 2160: Well run, Thisbe.
# 2161: Well shone, Moon. Truly, the moon shines with a
# 2162: good grace.
# 2163: The Lion shakes Thisbe's mantle, and exit
# 2164: Well moused, Lion.
# 2165: And so the lion vanished.
# 2166: And then came Pyramus.
# 2168: Pyramus
# 2169: Sweet Moon, I thank thee for thy sunny beams;
# 2170: I thank thee, Moon, for shining now so bright;
# 2171: For, by thy gracious, golden, glittering gleams,
# 2172: I trust to take of truest Thisby sight.
# 2173: But stay, O spite!
# 2174: But mark, poor knight,
# 2175: What dreadful dole is here!
# 2176: Eyes, do you see?
# 2177: How can it be?
# 2178: O dainty duck! O dear!
# 2179: Thy mantle good,
# 2180: What, stain'd with blood!
# 2181: Approach, ye Furies fell!
# 2182: O Fates, come, come,
# 2183: Cut thread and thrum;
# 2184: Quail, crush, conclude, and quell!
# 2185: This passion, and the death of a dear friend, would
# 2186: go near to make a man look sad.
# 2187: Beshrew my heart, but I pity the man.
# 2188: Pyramus
# 2189: O wherefore, Nature, didst thou lions frame?
# 2190: Since lion vile hath here deflower'd my dear:
# 2191: Which is--no, no--which was the fairest dame
# 2192: That lived, that loved, that liked, that look'd
# 2193: with cheer.
# 2194: Come, tears, confound;
# 2195: Out, sword, and wound
# 2196: The pap of Pyramus;
# 2197: Ay, that left pap,
# 2198: Where heart doth hop:
# 2199: Stabs himself
# 2200: Thus die I, thus, thus, thus.
# 2201: Now am I dead,
# 2202: Now am I fled;
# 2203: My soul is in the sky:
# 2204: Tongue, lose thy light;
# 2205: Moon take thy flight:
# 2207: Now die, die, die, die, die.
# 2208: Dies
# 2209: No die, but an ace, for him; for he is but one.
# 2210: Less than an ace, man; for he is dead; he is nothing.
# 2211: With the help of a surgeon he might yet recover, and
# 2212: prove an ass.
# 2213: How chance Moonshine is gone before Thisbe comes
# 2214: back and finds her lover?
# 2215: She will find him by starlight. Here she comes; and
# 2216: her passion ends the play.
# 2217: Re-enter Thisbe
# 2218: Methinks she should not use a long one for such a
# 2219: Pyramus: I hope she will be brief.
# 2220: A mote will turn the balance, which Pyramus, which
# 2221: Thisbe, is the better; he for a man, God warrant us;
# 2222: she for a woman, God bless us.
# 2223: She hath spied him already with those sweet eyes.
# 2224: And thus she means, videlicet:--
# 2225: Thisbe
# 2226: Asleep, my love?
# 2227: What, dead, my dove?
# 2228: O Pyramus, arise!
# 2229: Speak, speak. Quite dumb?
# 2230: Dead, dead? A tomb
# 2231: Must cover thy sweet eyes.
# 2232: These My lips,
# 2233: This cherry nose,
# 2234: These yellow cowslip cheeks,
# 2235: Are gone, are gone:
# 2236: Lovers, make moan:
# 2237: His eyes were green as leeks.
# 2238: O Sisters Three,
# 2239: Come, come to me,
# 2240: With hands as pale as milk;
# 2241: Lay them in gore,
# 2242: Since you have shore
# 2243: With shears his thread of silk.
# 2244: Tongue, not a word:
# 2245: Come, trusty sword;
# 2246: Come, blade, my breast imbrue:
# 2247: Stabs herself
# 2248: And, farewell, friends;
# 2249: Thus Thisby ends:
# 2250: Adieu, adieu, adieu.
# 2251: Dies
# 2252: Moonshine and Lion are left to bury the dead.
# 2253: Ay, and Wall too.
# 2254: [Starting up] No assure you; the wall is down that
# 2255: parted their fathers. Will it please you to see the
# 2256: epilogue, or to hear a Bergomask dance between two
# 2257: of our company?
# 2258: No epilogue, I pray you; for your play needs no
# 2259: excuse. Never excuse; for when the players are all
# 2260: dead, there needs none to be blamed. Marry, if he
# 2261: that writ it had played Pyramus and hanged himself
# 2262: in Thisbe's garter, it would have been a fine
# 2263: tragedy: and so it is, truly; and very notably
# 2264: discharged. But come, your Bergomask: let your
# 2265: epilogue alone.
# 2266: A dance
# 2267: The iron tongue of midnight hath told twelve:
# 2268: Lovers, to bed; 'tis almost fairy time.
# 2269: I fear we shall out-sleep the coming morn
# 2270: As much as we this night have overwatch'd.
# 2271: This palpable-gross play hath well beguiled
# 2272: The heavy gait of night. Sweet friends, to bed.
# 2273: A fortnight hold we this solemnity,
# 2274: In nightly revels and new jollity.
# 2275: Exeunt
# 2277: Now the hungry lion roars,
# 2278: And the wolf behowls the moon;
# 2279: Whilst the heavy ploughman snores,
# 2280: All with weary task fordone.
# 2281: Now the wasted brands do glow,
# 2282: Whilst the screech-owl, screeching loud,
# 2283: Puts the wretch that lies in woe
# 2284: In remembrance of a shroud.
# 2285: Now it is the time of night
# 2286: That the graves all gaping wide,
# 2287: Every one lets forth his sprite,
# 2288: In the church-way paths to glide:
# 2289: And we fairies, that do run
# 2290: By the triple Hecate's team,
# 2291: From the presence of the sun,
# 2292: Following darkness like a dream,
# 2293: Now are frolic: not a mouse
# 2294: Shall disturb this hallow'd house:
# 2295: I am sent with broom before,
# 2296: To sweep the dust behind the door.
# 2298: Through the house give gathering light,
# 2299: By the dead and drowsy fire:
# 2300: Every elf and fairy sprite
# 2301: Hop as light as bird from brier;
# 2302: And this ditty, after me,
# 2303: Sing, and dance it trippingly.
# 2304: First, rehearse your song by rote
# 2305: To each word a warbling note:
# 2306: Hand in hand, with fairy grace,
# 2307: Will we sing, and bless this place.
# 2308: Song and dance
# 2309: Now, until the break of day,
# 2310: Through this house each fairy stray.
# 2311: To the best bride-bed will we,
# 2312: Which by us shall blessed be;
# 2313: And the issue there create
# 2314: Ever shall be fortunate.
# 2315: So shall all the couples three
# 2316: Ever true in loving be;
# 2317: And the blots of Nature's hand
# 2318: Shall not in their issue stand;
# 2319: Never mole, hare lip, nor scar,
# 2320: Nor mark prodigious, such as are
# 2321: Despised in nativity,
# 2322: Shall upon their children be.
# 2323: With this field-dew consecrate,
# 2324: Every fairy take his gait;
# 2325: And each several chamber bless,
# 2326: Through this palace, with sweet peace;
# 2327: And the owner of it blest
# 2328: Ever shall in safety rest.
# 2329: Trip away; make no stay;
# 2330: Meet me all by break of day.
# 2331: Exeunt OBERON, TITANIA, and train
# 2332: If we shadows have offended,
# 2333: Think but this, and all is mended,
# 2334: That you have but slumber'd here
# 2335: While these visions did appear.
# 2336: And this weak and idle theme,
# 2337: No more yielding but a dream,
# 2338: Gentles, do not reprehend:
# 2339: if you pardon, we will mend:
# 2340: And, as I am an honest PUCK,
# 2341: If we have unearned luck
# 2342: Now to 'scape the serpent's tongue,
# 2343: We will make amends ere long;
# 2344: Else the PUCK a liar call;
# 2345: So, good night unto you all.
# 2346: Give me your hands, if we be friends,
# 2347: And Robin shall restore amends.
# 0.1572874208159794

# %%
print("CREATE: %.2fms per line" % create_time)
print("READ: %.2fms per line" % read_time)
print("UPDATE %.2fms per line" % update_time)
print("DELETE %.2fms per line" % delete_time)
# Out:
# CREATE: 0.30ms per line
# READ: 0.16ms per line
# UPDATE 0.44ms per line
# DELETE 0.46ms per line
